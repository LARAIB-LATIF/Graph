# %%
import matplotlib.pyplot as plt
arr1 = [1,3,5,7,9]
arr2 = [2,4,6,8,10]
arr3 = [1,4,5,8,9]
arr4 = [2,3,6,7,10]
plt.plot(arr1)
plt.plot(arr2)
plt.plot(arr3)
plt.plot(arr4)
plt.xlabel('students')
plt.ylabel('marks')
plt.title('Graph')
plt.show()
